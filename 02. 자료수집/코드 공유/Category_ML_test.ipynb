# %%
import pandas as pd

# %%
df = pd.read_csv('Category_Gusuk_Review_Final.csv', encoding='cp949')

# %%
df.columns
# Out:
# Index(['Attraction', 'Category', 'Subclass', 'Address', 'Tag', 'Participants'], dtype='object')

# %%
df['Subclass'].unique()
# Out:
# array(['도시,테마공원', '식물원,수목원', '전망대', '숲,숲길', '궁궐', '테마파크', '세계문화유산',
#        '자연,생태공원', '시장', '지역명소', '근린공원', '박물관', '기념물', '쇼핑복합시설',
#        '호수,연못,저수지', '강,하천', '체험마을', '도보코스', '시민공원', '문화,유적', '거리,골목',
#        '백화점', '섬', '테마공원', '성곽명', '북카페', '5성급', '산', '한식', '문구,팬시용품',
#        '전시관', '해물,생선요리', '캠핑,야영장', '화장품,향수', '상가,아케이드', '아쿠아리움', '국가유산',
#        '쇼핑센터,할인매장', '순대,순댓국', '워터파크', '떡볶이', '카페,디저트', '소고기구이', '돼지고기구이',
#        '3성급', '백숙,삼계탕', '도시, 테마공원', '한정식-일반', '족발,보쌈', '스케이트장', '수영장',
#        '서점', '보리밥', '장난감', '찜질방', '호텔', '냉면', '상가, 아케이드', '카페', '자연공원',
#        '유적지,사적지', '관람,체험', '아이스링크', '정육식당', '선글라스', '사진,스튜디오', '인테리어소품',
#        '온천,스파', '광장', '베이커리', '원예,화훼농원', '국수', '패션', '중식당', '한복', '보물',
#        '차', '전통숙소', '아울렛', '촬영장소', '미술,공예품', '게스트하우스', '냉', '박물', '신발',
#        '4급', '눈썰매장', '닭요리', '막국수', '낚시', '육류,고기요리', '스테이크,립', '분식',
#        '떡,한과', '이탈리아음식', '4성급', '독립서점', '칼국수,만두', '감자탕', '곰탕,설렁탕', '요트',
# ...

# %%
# 자연 관광 : '식물원,수목원|숲,숲길|자연,생태공원|산|호수,연못,저수지|강,하천|자연공원|계곡'
# 역사 관광 : '궁궐|세계문화유산|문화,유적|유적지,사적지|국가유산|보물|성곽명'
# 체험 관광 : '체험마을|도보코스|관람,체험|촬영장소|스킨스쿠버|요트|낚시|스크린골프장|캠핑,야영장
# 테마 관광 : '도시,테마공원|테마파크|지역명소|테마공원|테마카페|워터파크|온천,스파|동물원|아쿠아리움|수영장|스케이트장|아이스링크|눈썰매장'
# 문화 관광 : '박물관|전시관|미술,공예품|도서관|광장' #광장은 시간별 다양한 이벤트를 하는 곳으로 문화 관광에 속한다.
# 쇼핑 : '시장|쇼핑복합시설|백화점|상가,아케이드|쇼핑센터,할인매장|면세점|슈퍼,마트|독립서점|안경원|화장품,향수|전통공예|가구,인테리어|결혼예물|유기농산물마트|컴퓨터,모니터|가방,핸드백|종합패션|패션'
# 기타 : '전망대|시민공원'
# 숙소 : '5성급|4성급|3성급|2성급|1성급|호텔|모텔|게스트하우스|전통숙소|호스텔'
# 한식 : '한식해물,생선요리|소고기구이|돼지고기구이|백숙,삼계탕|한정식-일반|족발,보쌈|보리밥|냉면|정육식당|국수|백숙|순대,순댓국|떡볶이|찜질방|칼국수,만두|감자탕|곰탕,설렁탕|국밥|떡,한과|해장국|사찰음식|낙지요리|닭요리|막국수|육류,고기요리|쌈밥|추어탕|비빔밥|매운탕,해물탕|닭갈비|김밥|족발,보쌈|전,빈대떡'
# 중식 : '중식당|딤섬,중식만두'
# 일식 : '일식당|일식,초밥뷔페|초밥,롤|일본식라면'
# 양식 : '양식|이탈리아음식|프랑스음식|스테이크,립|샌드위치|브런치|베이커리'
# 기타음식 : '아시아음식'
# 카페 : '북카페|갤러리카페|카페,디저트|카페|브런치카페|홍차전문점|다방|한방카페'

# %%
df['Midclass'] = df['Subclass']

# %% [markdown]
# #### 광장&공원 : 공원은 도시계획에 있어서 분류가 난제입니다. and 데이터셋 광장은 대부분 이벤트 성이 강하기 때문에 문화관광으로 넣었습니다.
# - 인위적으로 만들어졌으므로
# - 역사지를 통해 구성되었으므로
# - 도시계획적으로 공개공지로 구성되었으므로
# - 이벤트성을 포함하고 있는 공원이 있음으로

# %%
category_map = {
    '자연관광': '식물원,수목원|숲,숲길|자연,생태공원|산|호수,연못,저수지|강,하천|자연공원|계곡|봉우리,고지|섬',
    '역사관광': '궁궐|세계문화유산|문화,유적|유적지,사적지|국가유산|보물|성곽명|기념물',
    '체험관광': '체험마을|도보코스|관람,체험|촬영장소|스킨스쿠버|요트|낚시|스크린골프장|캠핑,야영장|피부,체형관리|메이크업|사진,스튜디오',
    '테마관광': '거리,골목|도시,테마공원|테마파크|지역명소|테마공원|테마카페|워터파크|온천,스파|동물원|아쿠아리움|수영장|스케이트장|아이스링크|눈썰매장',
    '문화관광': '박물|박물관|전시관|미술,공예품|도서관|광장',
    '쇼핑': '정육점|휴대폰|상가, 아케이드|신발|아울렛|선글라스|음반,CD|장난감|서점|원예,화훼농원|문구,팬시용품|캐주얼웨어|인테리어소품|시장|쇼핑복합시설|백화점|상가,아케이드|쇼핑센터,할인매장|면세점|슈퍼,마트|독립서점|안경원|화장품,향수|전통공예|가구,인테리어|결혼예물|유기농산물마트|컴퓨터,모니터|가방,핸드백|종합패션|패션',
    '기타': '근린공원|전망대|시민공원',
    '숙소': '한복|5성급|4성급|3성급|2성급|1성급|4급|3급|호텔|모텔|게스트하우스|전통숙소|호스텔',
    '한식': '분식|종합분식|생선구이|장어,먹장어요리|곱창,막창,양|두부요리|전통,민속주점|냉|게요리|주꾸미요리|포장마차|오리요리|찌개,전골|죽|아귀찜,해물찜|기사식당|만두|닭볶음탕|해물,생선요리|해담채|한식해물,생선요리|소고기구이|돼지고기구이|백숙,삼계탕|한정식-일반|족발,보쌈|보리밥|냉면|정육식당|국수|백숙|순대,순댓국|떡볶이|찜질방|칼국수,만두|감자탕|곰탕,설렁탕|국밥|떡,한과|해장국|사찰음식|낙지요리|닭요리|막국수|육류,고기요리|쌈밥|추어탕|비빔밥|매운탕,해물탕|닭갈비|김밥|족발,보쌈|전,빈대떡',
    '중식': '양꼬치|중식당|딤섬,중식만두',
    '일식': '돈가스|샤브샤브|복어요리|일식당|일식,초밥뷔페|초밥,롤|일본식라면|생선회',
    '양식': '바(BAR)|그리스음식|멕시코,남미음식|맥주,호프|바닷가재요리|요리주점|뷔페|양식|이탈리아음식|프랑스음식|스테이크,립|샌드위치|브런치|베이커리',
    '기타음식': '베트남음식|태국음식|이북음식|인도음식|아시아음식',
    '카페': '베이글|차|빙수|북카페|갤러리카페|카페,디저트|카페|브런치카페|홍차전문점|다방|한방카페'
}

# %%
df.loc[df['Attraction'] == '서소문역사공원', 'Midclass'] = '역사관광'
df.loc[df['Attraction'] == '사육신공원', 'Midclass'] = '역사관광'

# %%
df['Midclass'] = df['Midclass'].replace('바(BAR)', '양식')

# %%
df[df['Subclass']=='근린공원']
# Out:
#     Attraction Category Midclass Subclass  \
# 13        낙산공원       관광       기타     근린공원
# 59        탑골공원       관광       기타     근린공원
# 71      용산가족공원       관광       기타     근린공원
# 87       선유도공원       관광       기타     근린공원
# 110      보라매공원       관광       기타     근린공원
# 119     마로니에공원       관광       기타     근린공원
# 144      사육신공원       관광       기타     근린공원
# 145    서소문역사공원       관광     역사관광     근린공원
# 148       삼청공원       관광       기타     근린공원
# 179     달맞이봉공원       관광       기타     근린공원
# 203     중랑장미공원       관광       기타     근린공원
# 205      여의도공원       관광       기타     근린공원
# 224  용산공원 반환부지       관광       기타     근린공원
# 229       양천공원       관광       기타     근린공원
# 231     오동근린공원       관광       기타     근린공원
# 250      용산역광장       관광       기타     근린공원
# 298       오목공원       관광       기타     근린공원
# 300       천호공원       관광       기타     근린공원
# 304      아시아공원       관광       기타     근린공원
# 332      서리풀공원       관광       기타     근린공원
# 393     양재근린공원       관광       기타     근린공원
# ...

# %%
df['Midclass'].unique()
# Out:
# array(['테마관광', '자연관광', '기타', '역사관광', '쇼핑', '문화관광', '체험관광', '카페', '숙소',
#        '한식', '양식', '중식', '일식', '기타음식'], dtype=object)

# %%
def update_categories(df, category_map):
    for category, keywords in category_map.items():
        keyword_list = keywords.split('|')
        pattern = '|'.join(keyword_list)
        df.loc[df['Midclass'].str.contains(pattern), 'Midclass'] = category
    return df

# %%
df = update_categories(df, category_map)
# Out:
# C:\Users\taeyoung\AppData\Local\Temp\ipykernel_24344\3834769967.py:5: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df.loc[df['Midclass'].str.contains(pattern), 'Midclass'] = category

# %%
df.columns
# Out:
# Index(['Attraction', 'Category', 'Midclass', 'Subclass', 'Address', 'Tag',
#        'Participants'],
#       dtype='object')

# %%
df = df[['Attraction','Category','Midclass', 'Subclass', 'Address', 'Tag', 'Participants']]

# %%
df.head()
# Out:
#   Attraction Category Midclass Subclass                   Address  \
# 0  동대문역사문화공원       관광     테마관광  도시,테마공원          서울특별시 중구 신당동 853
# 1      서울식물원       관광     자연관광  식물원,수목원  서울특별시 강서구 마곡동로 161 서울식물원
# 2      N서울타워       관광       기타      전망대       서울특별시 용산구 남산공원길 105
# 3        서울숲       관광     자연관광     숲,숲길         서울특별시 성동구 뚝섬로 273
# 4        경복궁       관광     역사관광       궁궐     서울특별시 종로구 사직로 161 경복궁
#
#                                                  Tag Participants
# 0  #2024_여행가는달과함께하는_발도장여행지#DDP#가족여행#걷기좋은길#관광지#데이트...           56
# 1  #2024_여행가는달과함께하는_발도장여행지#가족과함께#관광지#교육여행#미세먼지_피하...        5,204
# 2  #19_20한국관광100선#2024_여행가는달과함께하는_발도장여행지#21_22한국관...        5,100
# 3  #2024_여행가는달과함께하는_발도장여행지#23_24한국관광100선#가족여행#걷기길...          258
# 4  #15_16한국관광100선#17_18한국관광100선#19_20한국관광100선#202...        1,202

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(df['Midclass'], df['Category'], test_size=0.3, random_state=42)

# 텍스트 데이터를 TF-IDF 벡터로 변환
vectorizer = TfidfVectorizer()
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# 로지스틱 회귀 모델 학습
model = LogisticRegression()
model.fit(X_train_tfidf, y_train)

# 예측
y_pred = model.predict(X_test_tfidf)

# 평가
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9853479853479854
# Classification Report:
#                precision    recall  f1-score   support
#
#           관광       0.99      0.97      0.98       102
#           숙소       0.91      1.00      0.96        32
#           음식       1.00      0.99      1.00       139
#
#     accuracy                           0.99       273
#    macro avg       0.97      0.99      0.98       273
# weighted avg       0.99      0.99      0.99       273

# %%
df.to_csv('카테고리3분류.csv', encoding='cp949', index=False)

# %%
df = pd.read_csv('카테고리3분류.csv', encoding='cp949')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(df['Midclass'], df['Category'], test_size=0.2, random_state=34)

# 텍스트 데이터를 TF-IDF 벡터로 변환
vectorizer = TfidfVectorizer()
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# 로지스틱 회귀 모델 학습
model = LogisticRegression()
model.fit(X_train_tfidf, y_train)

# 예측
y_pred = model.predict(X_test_tfidf)

# 평가
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.989010989010989
# Classification Report:
#                precision    recall  f1-score   support
#
#           관광       1.00      0.97      0.98        60
#           숙소       0.95      1.00      0.97        18
#           음식       0.99      1.00      1.00       104
#
#     accuracy                           0.99       182
#    macro avg       0.98      0.99      0.98       182
# weighted avg       0.99      0.99      0.99       182

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(df['Subclass'], df['Midclass'], test_size=0.2, random_state=34) #34

# 텍스트 데이터를 TF-IDF 벡터로 변환
vectorizer = TfidfVectorizer()
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# 로지스틱 회귀 모델 학습
model = LogisticRegression()
model.fit(X_train_tfidf, y_train)

# 예측
y_pred = model.predict(X_test_tfidf)

# 평가
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8956043956043956
# Classification Report:
#                precision    recall  f1-score   support
#
#           기타       1.00      1.00      1.00         5
#         기타음식       1.00      0.40      0.57         5
#         문화관광       1.00      0.92      0.96        13
#           쇼핑       1.00      0.88      0.93        16
#           숙소       1.00      0.95      0.97        19
#           양식       1.00      1.00      1.00         7
#         역사관광       1.00      0.75      0.86         4
#           일식       1.00      0.88      0.93         8
#         자연관광       1.00      0.29      0.44         7
#           중식       1.00      0.86      0.92         7
#         체험관광       1.00      0.50      0.67         4
#           카페       1.00      0.86      0.92         7
#         테마관광       1.00      0.89      0.94         9
#           한식       0.79      1.00      0.88        71
#
#     accuracy                           0.90       182
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# 데이터 분할
X_train, X_test, y_train, y_test = train_test_split(df['Subclass'], df['Midclass'], test_size=0.2, random_state=34)

# 텍스트 데이터를 TF-IDF 벡터로 변환
vectorizer = TfidfVectorizer()
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# 로지스틱 회귀 모델 하이퍼파라미터 튜닝
param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],
    'solver': ['liblinear', 'lbfgs', 'newton-cg', 'sag', 'saga']
}

grid_search = GridSearchCV(LogisticRegression(), param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train_tfidf, y_train)

# 최적의 모델로 예측
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test_tfidf)

# 평가
print("Best Parameters:", grid_search.best_params_)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# c:\Python312\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# c:\Python312\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %%
df_2 = pd.read_csv('Naver_Final_v2.csv', encoding='cp949')

# %% [markdown]
# ### Good_Point 처리 해야...

# %%
df_2
# Out:
#       Attraction    Good_Point  Selected_People
# 0      동대문역사문화공원        뷰가 좋아요               22
# 1      동대문역사문화공원   관리가 잘 되어있어요               21
# 2      동대문역사문화공원      볼거리가 많아요               14
# 3      동대문역사문화공원     사진이 잘 나와요               12
# 4      동대문역사문화공원  산책로가 잘 되어있어요               12
# ...          ...           ...              ...
# 17469    파로스관광호텔     인테리어가 멋져요                2
# 17470    파로스관광호텔      주차하기 편해요                2
# 17471    파로스관광호텔     사진이 잘 나와요                1
# 17472    파로스관광호텔  수영장이 잘 되어있어요                1
# 17473    파로스관광호텔       방음이 잘돼요                1
#
# [17474 rows x 3 columns]
